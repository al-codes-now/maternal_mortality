# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from linearmodels import PanelOLS
import statsmodels.api as sm

# %%
df = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/final.csv')

# %%
#convert year to datetime
df['YEAR'] = pd.to_datetime(df['YEAR'], format='%Y')
#add column year to index
df=df.set_index('YEAR', append=True)
#swap indexes
df.index = df.index.swaplevel(0,1)

# %%
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1,inplace = True)

# %%
f = 'DEATH_RTE~LESS_HS+HS+SOM_COL+RTE_CHL+PRC_BLK+PRC_WHT+PRC_HISP+PRC_OTHER'

# %%
model = ols(formula=f, data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              DEATH_RTE   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     51.11
# Date:                Mon, 15 Feb 2021   Prob (F-statistic):           6.51e-71
# Time:                        14:43:24   Log-Likelihood:                -4788.1
# No. Observations:                1158   AIC:                             9594.
# Df Residuals:                    1149   BIC:                             9640.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     46.5765      1.377     33.814      0.000      43.874      49.279
# ...

# %% [markdown]
# **Trying Fixed Effects Model**

# %%
df
# Out:
#                                   measure           STATE       AGE  \
# YEAR
# 2011-01-01 0     Maternal mortality ratio  North Carolina  20 to 24
#            1     Maternal mortality ratio  North Carolina  25 to 29
#            2     Maternal mortality ratio  North Carolina  35 to 39
# 2012-01-01 3     Maternal mortality ratio        Nebraska  20 to 24
#            4     Maternal mortality ratio          Nevada  20 to 24
# ...                                   ...             ...       ...
# 2018-01-01 1153  Maternal mortality ratio      New Jersey  35 to 39
#            1154  Maternal mortality ratio      New Mexico  25 to 29
#            1155  Maternal mortality ratio        New York  20 to 24
#            1156  Maternal mortality ratio        New York  25 to 29
#            1157  Maternal mortality ratio        New York  35 to 39
#
#                               cause metric  DEATH_RTE   LESS_HS        HS  \
# YEAR
# ...

# %%
model_fe = PanelOLS(df.DEATH_RTE, df[['LESS_HS','HS','SOM_COL','RTE_CHL','PRC_BLK','PRC_WHT','PRC_HISP']], entity_effects = True) 
fe_res = model_fe.fit()

# %%
print(fe_res)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:              DEATH_RTE   R-squared:                        0.2597
# Estimator:                   PanelOLS   R-squared (Between):             -2.7297
# No. Observations:                1158   R-squared (Within):               0.2597
# Date:                Mon, Feb 15 2021   R-squared (Overall):             -1.7278
# Time:                        18:56:17   Log-likelihood                   -4785.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      57.118
# Entities:                          11   P-value                           0.0000
# Avg Obs:                       105.27   Distribution:                  F(7,1140)
# Min Obs:                       101.00
# Max Obs:                       111.00   F-statistic (robust):             57.118
#                                         P-value                           0.0000
# ...

# %%
df
# Out:
#                                   measure           STATE       AGE  \
# YEAR
# 2011-01-01 0     Maternal mortality ratio  North Carolina  20 to 24
#            1     Maternal mortality ratio  North Carolina  25 to 29
#            2     Maternal mortality ratio  North Carolina  35 to 39
# 2012-01-01 3     Maternal mortality ratio        Nebraska  20 to 24
#            4     Maternal mortality ratio          Nevada  20 to 24
# ...                                   ...             ...       ...
# 2018-01-01 1153  Maternal mortality ratio      New Jersey  35 to 39
#            1154  Maternal mortality ratio      New Mexico  25 to 29
#            1155  Maternal mortality ratio        New York  20 to 24
#            1156  Maternal mortality ratio        New York  25 to 29
#            1157  Maternal mortality ratio        New York  35 to 39
#
#                               cause metric  DEATH_RTE   LESS_HS        HS  \
# YEAR
# ...
