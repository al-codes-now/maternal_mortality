# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/final_df.csv')

# %%
mm = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/test.csv')

# %%
# Get indexes where name column has value PWGTP
indexNames = mm[mm['cause'] == 'All causes'].index
 
# Delete these row indexes from dataFrame
mm.drop(indexNames, inplace=True)

# %%
mm
# Out:
#                        measure        location     sex       age  \
# 6     Maternal mortality ratio  North Carolina  Female  15 to 19
# 7     Maternal mortality ratio  North Carolina  Female  20 to 24
# 8     Maternal mortality ratio  North Carolina  Female  25 to 29
# 9     Maternal mortality ratio  North Carolina  Female  30 to 34
# 10    Maternal mortality ratio  North Carolina  Female  35 to 39
# ...                        ...             ...     ...       ...
# 9787  Maternal mortality ratio        New York  Female  20 to 24
# 9788  Maternal mortality ratio        New York  Female  25 to 29
# 9789  Maternal mortality ratio        New York  Female  30 to 34
# 9790  Maternal mortality ratio        New York  Female  35 to 39
# 9791  Maternal mortality ratio        New York  Female  40 to 44
#
#                    cause metric  year        val      upper      lower
# 6     Maternal disorders   Rate  2011  13.022308  16.131454  10.376167
# 7     Maternal disorders   Rate  2011  11.677995  14.400828   9.394634
# 8     Maternal disorders   Rate  2011   8.313170  10.085487   6.772436
# 9     Maternal disorders   Rate  2011  16.913241  20.098258  14.011425
# 10    Maternal disorders   Rate  2011  36.753262  43.311142  30.820241
# ...                  ...    ...   ...        ...        ...        ...
# 9787  Maternal disorders   Rate  2018  20.765889  27.907258  14.747266
# 9788  Maternal disorders   Rate  2018  25.222863  34.789540  18.026227
# 9789  Maternal disorders   Rate  2018  27.733857  37.005362  20.713469
# 9790  Maternal disorders   Rate  2018  30.730396  40.198226  22.721978
# 9791  Maternal disorders   Rate  2018  72.790509  96.444794  54.325744
#
# [4896 rows x 10 columns]

# %%
mm.columns
# Out:
# Index(['measure', 'location', 'sex', 'age', 'cause', 'metric', 'year', 'val',
#        'upper', 'lower'],
#       dtype='object')

# %%
mm.drop(['sex', 'upper','lower'], axis = 1,inplace = True)

# %%
mm = mm.rename(columns = {'location':'STATE','age':'AGE','year':'YEAR','val':'DEATH_RTE'})

# %%
df = pd.merge(mm, df,  how='left', left_on=['STATE','YEAR','AGE'], right_on = ['STATE','YEAR','AGE'])

# %%
df.dropna(inplace = True)

# %%
df.to_csv('/Users/alexandrabruno/Documents/flatiron/data/final.csv')

# %%
f = 'DEATH_RTE~LESS_HS+HS+SOM_COL+RTE_CHL+PRC_BLK+PRC_WHT+PRC_HISP+PRC_OTHER'

# %%
model = ols(formula=f, data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              DEATH_RTE   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     51.11
# Date:                Mon, 15 Feb 2021   Prob (F-statistic):           6.51e-71
# Time:                        10:52:10   Log-Likelihood:                -4788.1
# No. Observations:                1158   AIC:                             9594.
# Df Residuals:                    1149   BIC:                             9640.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     46.5765      1.377     33.814      0.000      43.874      49.279
# LESS_HS      -98.5901      9.311    -10.588      0.000    -116.859     -80.321
# HS           -12.9472      9.929     -1.304      0.193     -32.428       6.534
# SOM_COL      -63.9955     32.161     -1.990      0.047    -127.095      -0.896
# RTE_CHL        0.0006      0.000      1.245      0.213      -0.000       0.002
# PRC_BLK      -43.1436     10.653     -4.050      0.000     -64.045     -22.242
# PRC_WHT      -47.1704     34.471     -1.368      0.171    -114.804      20.463
# PRC_HISP      11.9381     14.273      0.836      0.403     -16.065      39.941
# PRC_OTHER     26.0804      7.883      3.308      0.001      10.613      41.548
# ==============================================================================
# Omnibus:                      658.915   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6855.289
# Skew:                           2.451   Prob(JB):                         0.00
# Kurtosis:                      13.865   Cond. No.                     2.28e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
