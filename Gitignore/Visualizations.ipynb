# %% [markdown]
# # EDA

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
plt.style.use('seaborn')
from linearmodels import PanelOLS
import statsmodels.api as sm
import folium
import os
import json

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import MaxNLocator, FuncFormatter

# %%
df = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/IHME-GBD_2019_DATA-b82d657c-1.csv')

# %%
df
# Out:
#                      measure                  location     sex       age  \
# 0   Maternal mortality ratio  United States of America  Female  All Ages
# 1   Maternal mortality ratio  United States of America  Female  All Ages
# 2   Maternal mortality ratio  United States of America  Female  All Ages
# 3   Maternal mortality ratio  United States of America  Female  All Ages
# 4   Maternal mortality ratio  United States of America  Female  All Ages
# 5   Maternal mortality ratio  United States of America  Female  All Ages
# 6   Maternal mortality ratio  United States of America  Female  All Ages
# 7   Maternal mortality ratio  United States of America  Female  All Ages
# 8   Maternal mortality ratio  United States of America  Female  All Ages
# 9   Maternal mortality ratio  United States of America  Female  All Ages
# 10  Maternal mortality ratio  United States of America  Female  All Ages
# 11  Maternal mortality ratio  United States of America  Female  All Ages
#
#                               cause metric  year        val      upper  \
# 0   Maternal and neonatal disorders   Rate  2008  26.420103  26.999201
# 1   Maternal and neonatal disorders   Rate  2017  28.860973  31.004866
# 2   Maternal and neonatal disorders   Rate  2019  25.862139  27.680429
# 3   Maternal and neonatal disorders   Rate  2012  27.731284  28.299573
# 4   Maternal and neonatal disorders   Rate  2014  29.789435  30.479080
# 5   Maternal and neonatal disorders   Rate  2010  25.049636  25.568630
# 6   Maternal and neonatal disorders   Rate  2016  32.358240  34.124618
# 7   Maternal and neonatal disorders   Rate  2013  29.669500  30.262174
# 8   Maternal and neonatal disorders   Rate  2011  26.597784  27.151582
# 9   Maternal and neonatal disorders   Rate  2009  26.688709  27.272362
# 10  Maternal and neonatal disorders   Rate  2015  30.428473  31.399517
# 11  Maternal and neonatal disorders   Rate  2018  27.530725  29.816834
#
#         lower
# 0   25.742366
# 1   27.641595
# 2   24.665405
# 3   26.928769
# 4   28.874627
# 5   24.363153
# 6   31.128276
# 7   28.795101
# 8   25.868919
# 9   25.983838
# 10  29.395095
# 11  26.202566

# %%
# Set up the defaults
sns.set_style('whitegrid')
plt.figure(figsize=(15,8))

sns.lineplot(data=df, x="year", y="val",color = 'red')

# %% [markdown]
# ### Map visualization

# %%
state_geo = os.path.join('/Users/alexandrabruno/Desktop/','us-states.json')

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
df['abbrev'] = df['location'].map(us_state_abbrev)

# %%
df
# Out:
#                      measure              location     sex       age  \
# 0   Maternal mortality ratio              New York  Female  All Ages
# 1   Maternal mortality ratio        North Carolina  Female  All Ages
# 2   Maternal mortality ratio          North Dakota  Female  All Ages
# 3   Maternal mortality ratio                  Ohio  Female  All Ages
# 4   Maternal mortality ratio              Oklahoma  Female  All Ages
# 5   Maternal mortality ratio                Oregon  Female  All Ages
# 6   Maternal mortality ratio          Pennsylvania  Female  All Ages
# 7   Maternal mortality ratio          Rhode Island  Female  All Ages
# 8   Maternal mortality ratio        South Carolina  Female  All Ages
# 9   Maternal mortality ratio          South Dakota  Female  All Ages
# 10  Maternal mortality ratio             Tennessee  Female  All Ages
# 11  Maternal mortality ratio                 Texas  Female  All Ages
# 12  Maternal mortality ratio                  Utah  Female  All Ages
# 13  Maternal mortality ratio               Vermont  Female  All Ages
# 14  Maternal mortality ratio              Virginia  Female  All Ages
# 15  Maternal mortality ratio            Washington  Female  All Ages
# 16  Maternal mortality ratio         West Virginia  Female  All Ages
# 17  Maternal mortality ratio             Wisconsin  Female  All Ages
# 18  Maternal mortality ratio               Wyoming  Female  All Ages
# 19  Maternal mortality ratio               Alabama  Female  All Ages
# 20  Maternal mortality ratio                Alaska  Female  All Ages
# 21  Maternal mortality ratio               Arizona  Female  All Ages
# 22  Maternal mortality ratio              Arkansas  Female  All Ages
# 23  Maternal mortality ratio            California  Female  All Ages
# 24  Maternal mortality ratio              Colorado  Female  All Ages
# 25  Maternal mortality ratio           Connecticut  Female  All Ages
# 26  Maternal mortality ratio              Delaware  Female  All Ages
# 27  Maternal mortality ratio  District of Columbia  Female  All Ages
# 28  Maternal mortality ratio               Florida  Female  All Ages
# 29  Maternal mortality ratio               Georgia  Female  All Ages
# 30  Maternal mortality ratio                Hawaii  Female  All Ages
# 31  Maternal mortality ratio                 Idaho  Female  All Ages
# 32  Maternal mortality ratio              Illinois  Female  All Ages
# 33  Maternal mortality ratio               Indiana  Female  All Ages
# 34  Maternal mortality ratio                  Iowa  Female  All Ages
# 35  Maternal mortality ratio                Kansas  Female  All Ages
# 36  Maternal mortality ratio              Kentucky  Female  All Ages
# 37  Maternal mortality ratio             Louisiana  Female  All Ages
# 38  Maternal mortality ratio                 Maine  Female  All Ages
# 39  Maternal mortality ratio              Maryland  Female  All Ages
# 40  Maternal mortality ratio         Massachusetts  Female  All Ages
# 41  Maternal mortality ratio              Michigan  Female  All Ages
# 42  Maternal mortality ratio             Minnesota  Female  All Ages
# 43  Maternal mortality ratio           Mississippi  Female  All Ages
# 44  Maternal mortality ratio              Missouri  Female  All Ages
# 45  Maternal mortality ratio               Montana  Female  All Ages
# 46  Maternal mortality ratio              Nebraska  Female  All Ages
# 47  Maternal mortality ratio                Nevada  Female  All Ages
# 48  Maternal mortality ratio         New Hampshire  Female  All Ages
# 49  Maternal mortality ratio            New Jersey  Female  All Ages
# 50  Maternal mortality ratio            New Mexico  Female  All Ages
#
#                               cause metric  year        val       upper  \
# 0   Maternal and neonatal disorders   Rate  2018  32.546346   41.251102
# 1   Maternal and neonatal disorders   Rate  2018  23.785645   29.905453
# 2   Maternal and neonatal disorders   Rate  2018  30.211908   36.031517
# 3   Maternal and neonatal disorders   Rate  2018  26.425790   33.259358
# 4   Maternal and neonatal disorders   Rate  2018  32.579185   41.259049
# 5   Maternal and neonatal disorders   Rate  2018  18.177161   23.242569
# 6   Maternal and neonatal disorders   Rate  2018  25.727937   32.830562
# 7   Maternal and neonatal disorders   Rate  2018  20.101431   24.912314
# 8   Maternal and neonatal disorders   Rate  2018  38.705250   49.880631
# 9   Maternal and neonatal disorders   Rate  2018  25.789610   31.131320
# 10  Maternal and neonatal disorders   Rate  2018  24.455092   30.622554
# 11  Maternal and neonatal disorders   Rate  2018  33.740739   42.210478
# 12  Maternal and neonatal disorders   Rate  2018  18.872629   22.556473
# 13  Maternal and neonatal disorders   Rate  2018  21.536098   25.558279
# 14  Maternal and neonatal disorders   Rate  2018  21.298321   27.050515
# 15  Maternal and neonatal disorders   Rate  2018  15.024421   18.749909
# 16  Maternal and neonatal disorders   Rate  2018  22.081047   27.981672
# 17  Maternal and neonatal disorders   Rate  2018  22.664659   28.664259
# 18  Maternal and neonatal disorders   Rate  2018  28.265982   33.552899
# 19  Maternal and neonatal disorders   Rate  2018  30.071353   37.712660
# 20  Maternal and neonatal disorders   Rate  2018  14.404635   17.199516
# 21  Maternal and neonatal disorders   Rate  2018  18.847875   24.134583
# 22  Maternal and neonatal disorders   Rate  2018  42.997518   54.090992
# 23  Maternal and neonatal disorders   Rate  2018  19.833001   24.825970
# 24  Maternal and neonatal disorders   Rate  2018  17.100295   22.174212
# 25  Maternal and neonatal disorders   Rate  2018  17.736556   22.729864
# 26  Maternal and neonatal disorders   Rate  2018  17.789470   21.415241
# 27  Maternal and neonatal disorders   Rate  2018  81.887884  101.560614
# 28  Maternal and neonatal disorders   Rate  2018  30.411361   38.068072
# 29  Maternal and neonatal disorders   Rate  2018  55.649592   70.511557
# 30  Maternal and neonatal disorders   Rate  2018  23.373819   27.988400
# 31  Maternal and neonatal disorders   Rate  2018  27.795401   33.930798
# 32  Maternal and neonatal disorders   Rate  2018  22.612201   28.701097
# 33  Maternal and neonatal disorders   Rate  2018  29.614319   37.304058
# 34  Maternal and neonatal disorders   Rate  2018  21.005264   26.801874
# 35  Maternal and neonatal disorders   Rate  2018  24.129303   30.489861
# 36  Maternal and neonatal disorders   Rate  2018  28.595811   36.694791
# 37  Maternal and neonatal disorders   Rate  2018  42.656747   53.259505
# 38  Maternal and neonatal disorders   Rate  2018  21.672072   26.809662
# 39  Maternal and neonatal disorders   Rate  2018  32.558350   41.724619
# 40  Maternal and neonatal disorders   Rate  2018  12.563791   16.181117
# 41  Maternal and neonatal disorders   Rate  2018  31.284811   39.341152
# 42  Maternal and neonatal disorders   Rate  2018  15.028169   19.125159
# 43  Maternal and neonatal disorders   Rate  2018  37.449379   47.201551
# 44  Maternal and neonatal disorders   Rate  2018  29.461791   36.797314
# 45  Maternal and neonatal disorders   Rate  2018  35.813861   42.780830
# 46  Maternal and neonatal disorders   Rate  2018  21.270929   25.850332
# 47  Maternal and neonatal disorders   Rate  2018  15.030066   17.965757
# 48  Maternal and neonatal disorders   Rate  2018  27.202560   33.973874
# 49  Maternal and neonatal disorders   Rate  2018  35.215304   44.576083
# 50  Maternal and neonatal disorders   Rate  2018  32.880736   39.969472
#
#         lower abbrev
# 0   25.454796     NY
# 1   18.527475     NC
# 2   25.044349     ND
# 3   20.399764     OH
# 4   25.556163     OK
# 5   14.042546     OR
# 6   19.725486     PA
# 7   16.086065     RI
# 8   29.670432     SC
# 9   21.521343     SD
# 10  19.074703     TN
# 11  26.833822     TX
# 12  15.489778     UT
# 13  18.348006     VT
# 14  16.645341     VA
# 15  11.853368     WA
# 16  17.312125     WV
# 17  17.933979     WI
# 18  23.750748     WY
# 19  23.509444     AL
# 20  12.175441     AK
# 21  14.758107     AZ
# 22  33.902620     AR
# 23  15.571107     CA
# 24  13.268510     CO
# 25  13.547173     CT
# 26  14.774371     DE
# 27  65.867747     DC
# 28  23.585503     FL
# 29  43.717389     GA
# 30  19.671416     HI
# 31  22.697826     ID
# 32  17.696388     IL
# 33  22.957792     IN
# 34  16.381471     IA
# 35  18.603142     KS
# 36  22.555122     KY
# 37  32.091004     LA
# 38  17.675020     ME
# 39  25.352274     MD
# 40   9.681345     MA
# 41  24.237669     MI
# 42  11.845249     MN
# 43  29.321621     MS
# 44  22.809214     MO
# 45  30.131534     MT
# 46  17.561493     NE
# 47  12.250919     NV
# 48  21.858674     NH
# 49  27.223017     NJ
# 50  27.100197     NM

# %%
df = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/data_for_map.csv')

# %%
# Initialize the map:
m = folium.Map(location=[37, -102], zoom_start=5)

# %%
# Add the color for the chloropleth:
m.choropleth(
geo_data=state_geo,
 name='choropleth',
 data=df,
 columns=['abbrev', 'val'],
 key_on='feature.id',
 fill_color='YlGnBu',
 fill_opacity=0.7,
 line_opacity=0.2,
 legend_name='Maternal Mortality Ratio'
)
folium.LayerControl().add_to(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-44292a09fb6c> in <module>
#       1 # Add the color for the chloropleth:
# ----> 2 m.choropleth(
#       3 geo_data=state_geo,
#       4  name='choropleth',
#       5  data=df,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/folium.py in choropleth(self, *args, **kwargs)
#     414         )
#     415         from folium.features import Choropleth
# --> 416         self.add_child(Choropleth(*args, **kwargs))
#     417
#     418     def keep_in_front(self, *args):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1287                 smooth_factor=smooth_factor)
#    1288         else:
# -> 1289             self.geojson = GeoJson(
#    1290                 geo_data,
#    1291                 style_function=style_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker)
#     502             self.convert_to_feature_collection()
#     503             if self.style:
# --> 504                 self._validate_function(style_function, 'style_function')
#     505                 self.style_function = style_function
#     506                 self.style_map = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in _validate_function(self, func, name)
#     567         """
#     568         test_feature = self.data['features'][0]
# --> 569         if not callable(func) or not isinstance(func(test_feature), dict):
#     570             raise ValueError('{} should be a function that accepts items from '
#     571                              'data[\'features\'] and returns a dictionary.'
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in style_function(x)
#    1265
#    1266         def style_function(x):
# -> 1267             color, opacity = color_scale_fun(x)
#    1268             return {
#    1269                 'weight': line_weight,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in color_scale_fun(x)
#    1246
#    1247             def color_scale_fun(x):
# -> 1248                 key_of_x = get_by_key(x, key_on)
#    1249                 if key_of_x is None:
#    1250                     raise ValueError("key_on `{!r}` not found in GeoJSON.".format(key_on))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in get_by_key(obj, key)
#    1242             def get_by_key(obj, key):
#    1243                 return (obj.get(key, None) if len(key.split('.')) <= 1 else
# -> 1244                         get_by_key(obj.get(key.split('.')[0], None),
#    1245                                    '.'.join(key.split('.')[1:])))
#    1246
#
# ~/opt/anaconda3/lib/python3.8/site-packages/folium/features.py in get_by_key(obj, key)
#    1241
#    1242             def get_by_key(obj, key):
# -> 1243                 return (obj.get(key, None) if len(key.split('.')) <= 1 else
#    1244                         get_by_key(obj.get(key.split('.')[0], None),
#    1245                                    '.'.join(key.split('.')[1:])))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a4b9e47e6876469aae886284c493ce8b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a4b9e47e6876469aae886284c493ce8b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a4b9e47e6876469aae886284c493ce8b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a4b9e47e6876469aae886284c493ce8b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### STD rates over time

# %%
df = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/cdc.csv')

# %%
df
# Out:
#       Unnamed: 0  YEAR    STATE       AGE  RTE_CHL  RTE_GON
# 0              0  2018  Alabama  35 to 39    115.1     79.0
# 1              1  2018  Alabama  45 to 49    286.0    178.4
# 2              2  2018  Alabama  15 to 19    653.5    325.5
# 3              3  2018  Alabama  20 to 24   1705.9    657.8
# 4              4  2018  Alabama  40 to 44   4513.2   1285.3
# ...          ...   ...      ...       ...      ...      ...
# 5809        5809  2000  Wyoming  45 to 49     43.6      0.0
# 5810        5810  2000  Wyoming  15 to 19    151.2     34.4
# 5811        5811  2000  Wyoming  20 to 24    404.7     41.9
# 5812        5812  2000  Wyoming  40 to 44   1615.2     43.7
# 5813        5813  2000  Wyoming  25 to 29   1513.9     64.5
#
# [5814 rows x 6 columns]

# %%
sns.lineplot(data=df, x="RTE_CHL", y="AGE")

# %%
df[df['YEAR'] == 2018]
# Out:
#       Unnamed: 0  YEAR    STATE       AGE  RTE_CHL  RTE_GON
# 0              0  2018  Alabama  35 to 39    115.1     79.0
# 1              1  2018  Alabama  45 to 49    286.0    178.4
# 2              2  2018  Alabama  15 to 19    653.5    325.5
# 3              3  2018  Alabama  20 to 24   1705.9    657.8
# 4              4  2018  Alabama  40 to 44   4513.2   1285.3
# ...          ...   ...      ...       ...      ...      ...
# 5701        5701  2018  Wyoming  45 to 49    211.6     59.7
# 5702        5702  2018  Wyoming  15 to 19    451.5    103.8
# 5703        5703  2018  Wyoming  20 to 24   1026.9    211.7
# 5704        5704  2018  Wyoming  40 to 44   3087.0    278.6
# 5705        5705  2018  Wyoming  25 to 29   2892.8    185.5
#
# [306 rows x 6 columns]

# %%
chl = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/smaller_data/chl.csv')

# %% [markdown]
# ### Seaborn graphs

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.boxplot(x=tips["total_bill"])

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)
