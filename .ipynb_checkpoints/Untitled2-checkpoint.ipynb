# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/final_df.csv')

# %%
mm = pd.read_csv('/Users/alexandrabruno/Documents/flatiron/data/test.csv')

# %%
# Get indexes where name column has value PWGTP
indexNames = mm[mm['cause'] == 'All causes'].index
 
# Delete these row indexes from dataFrame
mm.drop(indexNames, inplace=True)

# %%
del mm['upper']
del mm['measure']
del mm['sex']
del mm['lower']

# %%
del mm['cause']
del mm['rate']
del mm['sex']
del mm['lower']

# %%
mm = mm.rename(columns = {'location':'STATE','age':'AGE','year':'YEAR'})

# %%
mm = mm.rename(columns = {'val':'DEATH_RTE'})

# %%
df = pd.merge(mm, df,  how='left', left_on=['STATE','YEAR','AGE'], right_on = ['STATE','YEAR','AGE'])

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                STATE       AGE               cause metric  YEAR  DEATH_RTE  \
# 1     North Carolina  20 to 24  Maternal disorders   Rate  2011  11.677995
# 2     North Carolina  25 to 29  Maternal disorders   Rate  2011   8.313170
# 4     North Carolina  35 to 39  Maternal disorders   Rate  2011  36.753262
# 13          Nebraska  20 to 24  Maternal disorders   Rate  2012  14.294244
# 19            Nevada  20 to 24  Maternal disorders   Rate  2012   9.903277
# ...              ...       ...                 ...    ...   ...        ...
# 4882      New Jersey  35 to 39  Maternal disorders   Rate  2018  29.078901
# 4886      New Mexico  25 to 29  Maternal disorders   Rate  2018  22.928582
# 4891        New York  20 to 24  Maternal disorders   Rate  2018  20.765889
# 4892        New York  25 to 29  Maternal disorders   Rate  2018  25.222863
# 4894        New York  35 to 39  Maternal disorders   Rate  2018  30.730396
#
# ...

# %%
df.columns
# Out:
# Index(['STATE', 'AGE', 'cause', 'metric', 'YEAR', 'DEATH_RTE', 'RTE_CHL',
#        'RTE_GON', 'PRC_BLK', 'PRC_WHT', 'PRC_HISP', 'PRC_OTHER'],
#       dtype='object')

# %%
f = 'DEATH_RTE~YEAR+RTE_CHL+RTE_GON+PRC_BLK+PRC_WHT+PRC_HISP'

# %%
model = (formula=f, data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-dbb3d57d2032> in <module>
# ----> 1 model = PanelOLS(formula=f, data=df).fit()
#
# NameError: name 'PanelOLS' is not defined

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              DEATH_RTE   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     37.27
# Date:                Sat, 13 Feb 2021   Prob (F-statistic):           5.04e-43
# Time:                        13:30:55   Log-Likelihood:                -8302.1
# No. Observations:                1994   AIC:                         1.662e+04
# Df Residuals:                    1987   BIC:                         1.666e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1001.7821    179.257     -5.589      0.000   -1353.334    -650.230
# ...
